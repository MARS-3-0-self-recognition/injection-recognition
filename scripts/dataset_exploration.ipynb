# %%
import pandas as pd

df = pd.read_csv("data/wikisum_capitalization_treatments_6_10.csv")

# %%
df
# Out:
#         id                                             title  \
# 0  train_5  How to Avoid Self Sabotage when You Feel Unloved
# 1  train_6                        How to Make Flavored Water
# 2  train_7                             How to Play Powerball
# 3  train_8                  How to Apply Heat Transfer Vinyl
# 4  train_9                       How to Screen Print at Home
#
#                                                 text  \
# 0  Resist the temptation to self-medicate. When y...
# 1  Make citrus water. Wash 1–3 citrus fruits per ...
# 2  Know where (and to whom) Powerball tickets are...
# 3  Choose and purchase vinyl. There are many colo...
# 4  Purchase a canvas stretcher frame at a craft o...
#
#                                              summary  \
# 0  If you're feeling unloved, you might engage in...
# 1  To make flavored water, slice citrus fruits in...
# 2  To play Powerball, start by selecting 5 number...
# 3  To apply heat transfer vinyl, start by heating...
# ...

# %%
# Calculate average word count of text column
n_words = df.text.str.split().str.len()
n_words
# Out:
# 0    1986
# 1     896
# 2    1754
# 3     815
# 4    1399
# Name: text, dtype: int64

# %%
import anthropic

def summary(text, style):
    # Initialize Anthropic client
    client = anthropic.Anthropic()
    try:
        response = client.messages.create(
            model="claude-sonnet-4-20250514",
            max_tokens=2000,
            messages=[{
                "role": "user", 
                "content": f"Please provide a plain-text, single-paragraph {style} summary of the following text:\n\n{text}"
            }]
        )
        return response.content[0].text
    except Exception as e:
        print(f"Error generating summary: {e}")
        return ""

# Function to generate summary with customizable style
def generate_summaries(df, style):
    df[f'sonnet_{style}'] = df['text'].apply(lambda x: summary(x, style))

# %%
concise_summary = summary(df.text[0], "concise")
concise_summary
# Out:
# "When feeling unloved and experiencing emotional pain, it's important to avoid self-medicating with substances, unhealthy behaviors, or destructive habits, and instead focus on positive coping strategies. Surround yourself with positive influences while removing negative ones, find creative outlets for your pain through art or writing, challenge negative thought patterns by reframing them more positively, and actively ask for support rather than expecting others to read your mind. Build connections by looking for shared similarities with others, practice empathy by improving your listening skills, volunteer to help those in need, and identify your personal strengths to boost self-worth. Set meaningful goals, pursue your passions and hobbies, maintain your physical health through proper diet and exercise, and consider professional help through therapy, medication for depression if needed, or support groups to address underlying issues and develop healthy coping skills."

# %%
from pprint import pprint

pprint(concise_summary)
# Out:
# ("When feeling unloved and experiencing emotional pain, it's important to "
#  'avoid self-medicating with substances, unhealthy behaviors, or destructive '
#  'habits, and instead focus on positive coping strategies. Surround yourself '
#  'with positive influences while removing negative ones, find creative outlets '
#  'for your pain through art or writing, challenge negative thought patterns by '
#  'reframing them more positively, and actively ask for support rather than '
#  'expecting others to read your mind. Build connections by looking for shared '
#  'similarities with others, practice empathy by improving your listening '
#  'skills, volunteer to help those in need, and identify your personal '
#  'strengths to boost self-worth. Set meaningful goals, pursue your passions '
#  'and hobbies, maintain your physical health through proper diet and exercise, '
#  'and consider professional help through therapy, medication for depression if '
# ...

# %%
n_concise = len(concise_summary.split())
n_concise
# Out:
# 137

# %%
long_summary = summary(df.text[0], "long")
pprint(long_summary)

n_long = len(long_summary.split())
pprint(n_long)
# Out:
# ("When feeling emotionally hurt or unloved, it's important to avoid "
#  'self-medicating with substances, excessive behaviors, or other harmful '
#  'coping mechanisms, and instead focus on building a healthier lifestyle and '
#  'mindset. Surround yourself with positive influences, remove toxic '
#  'relationships, and find creative outlets like art, writing, or music to '
#  'channel your pain constructively. Challenge negative thought patterns by '
#  'questioning their validity and reframing them more positively, while '
#  'actively asking for support from others rather than expecting them to read '
#  'your mind. Work on building connections by focusing on similarities with '
#  'others rather than differences, practicing empathy through better listening '
#  'skills, and volunteering to help those in need. Strengthen your self-worth '
#  'by identifying your personal strengths, setting and working toward '
# ...

# %%
very_long_summary = summary(df.text[0], "very long")
pprint(very_long_summary)

n_very_long = len(very_long_summary.split())
pprint(n_very_long)
# Out:
# ('To overcome feelings of being unloved and prevent self-destructive '
#  "behaviors, it's crucial to resist the temptation to self-medicate with "
#  'substances, excessive eating, shopping, or risky sexual behavior, as these '
#  'may provide temporary relief but can lead to addiction and greater long-term '
#  'problems; instead, surround yourself with positive influences by carefully '
#  'choosing your social group and removing negative relationships that '
#  'encourage unhealthy behaviors, while actively seeking out new friendships if '
#  'necessary. Channel emotional pain into creative outlets like writing, '
#  'painting, music, or dance, which can help heal feelings of rejection and '
#  'reduce stress and anxiety, while also challenging negative thought patterns '
#  'by identifying and questioning self-defeating thoughts like "nobody cares '
#  'about me" through reality testing and reframing them into more positive, '
# ...

# %%
n_long = df.sonnet_long.str.split().str.len()
n_long
# Out:
# 0    888
# 1    680
# 2    731
# 3    411
# 4    671
# Name: sonnet_long, dtype: int64

# %%
df[["id", "title", "text"]].to_csv("data/wikihow.csv", index=False)
